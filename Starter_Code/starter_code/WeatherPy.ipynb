# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 576

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
# Define your OpenWeatherMap API key
api_key = weather_api_key
url = "https://api.openweathermap.org/data/2.5/weather"
# Define an empty list to fetch the weather data for each city
city_data = []
# Print to logger
print("Beginning Data Retrieval")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={api_key}&units=metric"
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | invercargill
# Processing Record 2 of Set 1 | plastun
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# Processing Record 4 of Set 1 | uturoa
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 7 of Set 1 | el porvenir
# Processing Record 8 of Set 1 | cole harbour
# Processing Record 9 of Set 1 | isola di capo rizzuto
# Processing Record 10 of Set 1 | ilulissat
# Processing Record 11 of Set 1 | nyurba
# Processing Record 12 of Set 1 | qaqortoq
# Processing Record 13 of Set 1 | antofagasta
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | udachny
# Processing Record 18 of Set 1 | kavieng
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | bubaque
# Processing Record 21 of Set 1 | pampa del infierno
# Processing Record 22 of Set 1 | aasiaat
# Processing Record 23 of Set 1 | mejit
# Processing Record 24 of Set 1 | nemuro
# Processing Record 25 of Set 1 | holyhead
# Processing Record 26 of Set 1 | keflavik
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | port-aux-francais
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | lihue
# Processing Record 31 of Set 1 | yichun
# Processing Record 32 of Set 1 | noumea
# Processing Record 33 of Set 1 | tazacorte
# Processing Record 34 of Set 1 | chonchi
# Processing Record 35 of Set 1 | tuineje
# Processing Record 36 of Set 1 | peterhead
# Processing Record 37 of Set 1 | isafjordur
# Processing Record 38 of Set 1 | stanley
# Processing Record 39 of Set 1 | pantai remis
# Processing Record 40 of Set 1 | waitangi
# Processing Record 41 of Set 1 | newman
# Processing Record 42 of Set 1 | samamea
# City not found. Skipping...
# Processing Record 43 of Set 1 | nizhniy kuranakh
# Processing Record 44 of Set 1 | geraldton
# Processing Record 45 of Set 1 | villamontes
# Processing Record 46 of Set 1 | tommot
# Processing Record 47 of Set 1 | friedland
# Processing Record 48 of Set 1 | margaret river
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | nyrob
# Processing Record 0 of Set 2 | bethel
# Processing Record 1 of Set 2 | phibun mangsahan
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 4 of Set 2 | olonkinbyen
# Processing Record 5 of Set 2 | grytviken
# Processing Record 6 of Set 2 | kurumkan
# Processing Record 7 of Set 2 | syas'stroy
# Processing Record 8 of Set 2 | hamilton
# Processing Record 9 of Set 2 | bilibino
# Processing Record 10 of Set 2 | coquimbo
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | sisimiut
# Processing Record 13 of Set 2 | rancho palos verdes
# Processing Record 14 of Set 2 | pacific grove
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | evergreen
# Processing Record 17 of Set 2 | afaahiti
# Processing Record 18 of Set 2 | balikpapan
# Processing Record 19 of Set 2 | banmankhi
# Processing Record 20 of Set 2 | san patricio
# Processing Record 21 of Set 2 | mahtomedi
# Processing Record 22 of Set 2 | grand forks
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | severo-yeniseyskiy
# Processing Record 27 of Set 2 | bonham
# Processing Record 28 of Set 2 | kembe
# Processing Record 29 of Set 2 | chishmy
# Processing Record 30 of Set 2 | tura
# Processing Record 31 of Set 2 | kelso
# Processing Record 32 of Set 2 | papatowai
# Processing Record 33 of Set 2 | as sulayyil
# Processing Record 34 of Set 2 | lloydminster
# Processing Record 35 of Set 2 | thunder bay
# Processing Record 36 of Set 2 | shimoda
# Processing Record 37 of Set 2 | mora
# Processing Record 38 of Set 2 | sidrolandia
# Processing Record 39 of Set 2 | puerto princesa
# Processing Record 40 of Set 2 | chibougamau
# Processing Record 41 of Set 2 | hobyo
# Processing Record 42 of Set 2 | suntar
# Processing Record 43 of Set 2 | skien
# Processing Record 44 of Set 2 | tamanrasset
# Processing Record 45 of Set 2 | port saint john's
# Processing Record 46 of Set 2 | atafu village
# Processing Record 47 of Set 2 | west island
# Processing Record 48 of Set 2 | polyarnyy
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 0 of Set 3 | daru
# Processing Record 1 of Set 3 | talnakh
# Processing Record 2 of Set 3 | baikunthpur
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | wynyard
# Processing Record 6 of Set 3 | phnom penh
# Processing Record 7 of Set 3 | ambon
# Processing Record 8 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 3 | waingapu
# Processing Record 10 of Set 3 | rongelap
# Processing Record 11 of Set 3 | vorgashor
# Processing Record 12 of Set 3 | saint-francois
# Processing Record 13 of Set 3 | sidi ifni
# Processing Record 14 of Set 3 | russkaya polyana
# Processing Record 15 of Set 3 | broken hill
# Processing Record 16 of Set 3 | tughyl
# Processing Record 17 of Set 3 | kaa-khem
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | toliara
# Processing Record 21 of Set 3 | adra
# Processing Record 22 of Set 3 | male
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | sinabang
# Processing Record 25 of Set 3 | blackmans bay
# Processing Record 26 of Set 3 | mayna
# Processing Record 27 of Set 3 | xai-xai
# Processing Record 28 of Set 3 | puerto natales
# Processing Record 29 of Set 3 | bovril
# Processing Record 30 of Set 3 | pauini
# Processing Record 31 of Set 3 | acapulco de juarez
# Processing Record 32 of Set 3 | altagracia de orituco
# Processing Record 33 of Set 3 | ta`u
# Processing Record 34 of Set 3 | arkalyk
# Processing Record 35 of Set 3 | vadso
# Processing Record 36 of Set 3 | bargara
# City not found. Skipping...
# Processing Record 37 of Set 3 | mount isa
# Processing Record 38 of Set 3 | puerto real
# Processing Record 39 of Set 3 | jaithari
# Processing Record 40 of Set 3 | ola
# Processing Record 41 of Set 3 | mooloolaba
# Processing Record 42 of Set 3 | kapuskasing
# Processing Record 43 of Set 3 | lichinga
# Processing Record 44 of Set 3 | nevers
# Processing Record 45 of Set 3 | verkhnevilyuysk
# Processing Record 46 of Set 3 | manjeshvar
# Processing Record 47 of Set 3 | ahraura
# Processing Record 48 of Set 3 | pierre
# Processing Record 49 of Set 3 | dudinka
# Processing Record 0 of Set 4 | anadyr
# Processing Record 1 of Set 4 | nova xavantina
# Processing Record 2 of Set 4 | peshawar
# Processing Record 3 of Set 4 | soe
# Processing Record 4 of Set 4 | santana
# Processing Record 5 of Set 4 | mabaruma
# Processing Record 6 of Set 4 | corinto
# Processing Record 7 of Set 4 | inirida
# Processing Record 8 of Set 4 | amlapura
# Processing Record 9 of Set 4 | fale old settlement
# Processing Record 10 of Set 4 | fort bragg
# Processing Record 11 of Set 4 | chifeng
# Processing Record 12 of Set 4 | warmbad
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | tual
# Processing Record 15 of Set 4 | brak
# Processing Record 16 of Set 4 | wailua homesteads
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | nuuk
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | halmstad
# Processing Record 21 of Set 4 | kish
# Processing Record 22 of Set 4 | mikomeseng
# Processing Record 23 of Set 4 | st. john's
# Processing Record 24 of Set 4 | prince rupert
# Processing Record 25 of Set 4 | la crosse
# Processing Record 26 of Set 4 | kroya
# Processing Record 27 of Set 4 | nar'yan-mar
# Processing Record 28 of Set 4 | ghat
# Processing Record 29 of Set 4 | khorugh
# Processing Record 30 of Set 4 | rawai
# Processing Record 31 of Set 4 | takamaka
# City not found. Skipping...
# Processing Record 32 of Set 4 | pariaman
# Processing Record 33 of Set 4 | vikulovo
# Processing Record 34 of Set 4 | bredasdorp
# Processing Record 35 of Set 4 | belyy yar
# Processing Record 36 of Set 4 | benguela
# Processing Record 37 of Set 4 | thief river falls
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | strezhevoy
# Processing Record 40 of Set 4 | semenivka
# Processing Record 41 of Set 4 | hodos
# Processing Record 42 of Set 4 | reyes
# Processing Record 43 of Set 4 | colonia
# Processing Record 44 of Set 4 | lufkin
# Processing Record 45 of Set 4 | yangor
# City not found. Skipping...
# Processing Record 46 of Set 4 | butte
# Processing Record 47 of Set 4 | unai
# Processing Record 48 of Set 4 | constantia
# Processing Record 49 of Set 4 | saint-philippe
# Processing Record 0 of Set 5 | moyynkum
# Processing Record 1 of Set 5 | iskateley
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | kudymkar
# Processing Record 4 of Set 5 | lerwick
# Processing Record 5 of Set 5 | okny
# Processing Record 6 of Set 5 | shitanjing
# Processing Record 7 of Set 5 | manacapuru
# Processing Record 8 of Set 5 | saipan
# Processing Record 9 of Set 5 | port hedland
# Processing Record 10 of Set 5 | kerikeri
# Processing Record 11 of Set 5 | dzuunharaa
# Processing Record 12 of Set 5 | hitachi
# Processing Record 13 of Set 5 | mar del plata
# Processing Record 14 of Set 5 | orita eruwa
# Processing Record 15 of Set 5 | prainha
# Processing Record 16 of Set 5 | cairns city
# City not found. Skipping...
# Processing Record 17 of Set 5 | lebu
# Processing Record 18 of Set 5 | kalamata
# Processing Record 19 of Set 5 | wamba
# Processing Record 20 of Set 5 | sadjoavato
# City not found. Skipping...
# Processing Record 21 of Set 5 | hawaiian paradise park
# Processing Record 22 of Set 5 | burnie
# Processing Record 23 of Set 5 | hanko
# Processing Record 24 of Set 5 | juan griego
# Processing Record 25 of Set 5 | siroki brijeg
# Processing Record 26 of Set 5 | suez
# Processing Record 27 of Set 5 | saint-leu
# Processing Record 28 of Set 5 | neryungri
# Processing Record 29 of Set 5 | sabang
# Processing Record 30 of Set 5 | selfoss
# Processing Record 31 of Set 5 | mukalla
# Processing Record 32 of Set 5 | bel ombre
# Processing Record 33 of Set 5 | vernon
# Processing Record 34 of Set 5 | cosquin
# Processing Record 35 of Set 5 | huarmey
# Processing Record 36 of Set 5 | cambria
# Processing Record 37 of Set 5 | utrik
# Processing Record 38 of Set 5 | kertih
# Processing Record 39 of Set 5 | crane
# Processing Record 40 of Set 5 | badger
# Processing Record 41 of Set 5 | wyndham vale
# Processing Record 42 of Set 5 | kyshtovka
# Processing Record 43 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 44 of Set 5 | port alfred
# Processing Record 45 of Set 5 | tazovsky
# Processing Record 46 of Set 5 | al ghayzah
# Processing Record 47 of Set 5 | kudahuvadhoo
# Processing Record 48 of Set 5 | bandundu
# Processing Record 49 of Set 5 | kentville
# Processing Record 0 of Set 6 | kiama
# Processing Record 1 of Set 6 | yishui
# Processing Record 2 of Set 6 | whitehorse
# Processing Record 3 of Set 6 | yegorlykskaya
# Processing Record 4 of Set 6 | ariquemes
# Processing Record 5 of Set 6 | huilong
# Processing Record 6 of Set 6 | alice springs
# Processing Record 7 of Set 6 | happy valley-goose bay
# Processing Record 8 of Set 6 | klyuchi
# Processing Record 9 of Set 6 | haiku-pauwela
# Processing Record 10 of Set 6 | mermoz boabab
# Processing Record 11 of Set 6 | manokwari
# Processing Record 12 of Set 6 | mozdok
# Processing Record 13 of Set 6 | tolanaro
# Processing Record 14 of Set 6 | puerto aysen
# Processing Record 15 of Set 6 | olyokminsk
# Processing Record 16 of Set 6 | qobustan
# Processing Record 17 of Set 6 | bonthe
# Processing Record 18 of Set 6 | cannonvale
# Processing Record 19 of Set 6 | aswan
# Processing Record 20 of Set 6 | tulun
# Processing Record 21 of Set 6 | atherton
# Processing Record 22 of Set 6 | teknaf
# Processing Record 23 of Set 6 | north bend
# Processing Record 24 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 25 of Set 6 | new richmond
# Processing Record 26 of Set 6 | ayorou
# Processing Record 27 of Set 6 | kingston
# Processing Record 28 of Set 6 | georgetown
# Processing Record 29 of Set 6 | louis trichardt
# Processing Record 30 of Set 6 | dhidhdhoo
# Processing Record 31 of Set 6 | guerrero negro
# Processing Record 32 of Set 6 | giado
# Processing Record 33 of Set 6 | luderitz
# Processing Record 34 of Set 6 | parkes
# Processing Record 35 of Set 6 | williams lake
# Processing Record 36 of Set 6 | sola
# Processing Record 37 of Set 6 | inhambane
# Processing Record 38 of Set 6 | nizhneudinsk
# Processing Record 39 of Set 6 | vilyuchinsk
# Processing Record 40 of Set 6 | gaalkacyo
# Processing Record 41 of Set 6 | saint-joseph
# Processing Record 42 of Set 6 | novoishimskiy
# Processing Record 43 of Set 6 | port mathurin
# Processing Record 44 of Set 6 | bridgewater
# Processing Record 45 of Set 6 | ngama
# Processing Record 46 of Set 6 | chernyshevsk
# Processing Record 47 of Set 6 | taichung
# Processing Record 48 of Set 6 | enewetak
# Processing Record 49 of Set 6 | gadzhiyevo
# Processing Record 0 of Set 7 | pundong
# Processing Record 1 of Set 7 | savanna-la-mar
# Processing Record 2 of Set 7 | fontenay-le-comte
# Processing Record 3 of Set 7 | merizo village
# Processing Record 4 of Set 7 | hadibu
# Processing Record 5 of Set 7 | huancabamba
# Processing Record 6 of Set 7 | beya
# Processing Record 7 of Set 7 | laguna
# Processing Record 8 of Set 7 | nolensville
# Processing Record 9 of Set 7 | lucaya
# Processing Record 10 of Set 7 | shalqar
# Processing Record 11 of Set 7 | turbat
# Processing Record 12 of Set 7 | egilsstadir
# Processing Record 13 of Set 7 | cestos city
# Processing Record 14 of Set 7 | new norfolk
# Processing Record 15 of Set 7 | college
# Processing Record 16 of Set 7 | akureyri
# Processing Record 17 of Set 7 | hithadhoo
# Processing Record 18 of Set 7 | labe
# Processing Record 19 of Set 7 | katsuura
# Processing Record 20 of Set 7 | ouesso
# Processing Record 21 of Set 7 | jutai
# Processing Record 22 of Set 7 | yigo village
# Processing Record 23 of Set 7 | kristiansund
# Processing Record 24 of Set 7 | susuman
# Processing Record 25 of Set 7 | labrador city
# Processing Record 26 of Set 7 | nikolayevsk-on-amure
# Processing Record 27 of Set 7 | alofi
# Processing Record 28 of Set 7 | ulladulla
# Processing Record 29 of Set 7 | vorkuta
# Processing Record 30 of Set 7 | perth
# Processing Record 31 of Set 7 | pasuquin
# Processing Record 32 of Set 7 | keetmanshoop
# Processing Record 33 of Set 7 | that phanom
# Processing Record 34 of Set 7 | al kut
# Processing Record 35 of Set 7 | soderhamn
# Processing Record 36 of Set 7 | barcelos
# Processing Record 37 of Set 7 | najran
# Processing Record 38 of Set 7 | seria
# Processing Record 39 of Set 7 | lida
# Processing Record 40 of Set 7 | buala
# Processing Record 41 of Set 7 | vanino
# Processing Record 42 of Set 7 | gebeit
# Processing Record 43 of Set 7 | corn island
# Processing Record 44 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 45 of Set 7 | kotlas
# Processing Record 46 of Set 7 | port de pollenca
# Processing Record 47 of Set 7 | castillos
# Processing Record 48 of Set 7 | molchanovo
# Processing Record 49 of Set 7 | brookings
# Processing Record 0 of Set 8 | remire-montjoly
# Processing Record 1 of Set 8 | midvagur
# Processing Record 2 of Set 8 | bonga
# Processing Record 3 of Set 8 | kailua-kona
# Processing Record 4 of Set 8 | mount pearl
# Processing Record 5 of Set 8 | mount gambier
# Processing Record 6 of Set 8 | siniscola
# Processing Record 7 of Set 8 | kudepsta
# Processing Record 8 of Set 8 | fort mcmurray
# Processing Record 9 of Set 8 | puerto baquerizo moreno
# Processing Record 10 of Set 8 | bobo-dioulasso
# Processing Record 11 of Set 8 | callao
# Processing Record 12 of Set 8 | saratamata
# City not found. Skipping...
# Processing Record 13 of Set 8 | labuan
# Processing Record 14 of Set 8 | sur
# Processing Record 15 of Set 8 | ocotlan de morelos
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | kidatu
# Processing Record 18 of Set 8 | riyadh
# Processing Record 19 of Set 8 | vila franca do campo
# Processing Record 20 of Set 8 | belmonte
# Processing Record 21 of Set 8 | zhaotong
# Processing Record 22 of Set 8 | tamiahua
# Processing Record 23 of Set 8 | nouadhibou
# Processing Record 24 of Set 8 | bluefields
# Processing Record 25 of Set 8 | ancud
# Processing Record 26 of Set 8 | gillette
# Processing Record 27 of Set 8 | fort st. john
# Processing Record 28 of Set 8 | port blair
# Processing Record 29 of Set 8 | hirara
# Processing Record 30 of Set 8 | eraan
# Processing Record 31 of Set 8 | bargaal
# Processing Record 32 of Set 8 | arteche
# Processing Record 33 of Set 8 | naama
# Processing Record 34 of Set 8 | tot'ma
# Processing Record 35 of Set 8 | raojan
# Processing Record 36 of Set 8 | pisco
# Processing Record 37 of Set 8 | city of balikpapan
# Processing Record 38 of Set 8 | qaisumah
# Processing Record 39 of Set 8 | akhtubinsk
# Processing Record 40 of Set 8 | penzance
# Processing Record 41 of Set 8 | auki
# Processing Record 42 of Set 8 | okhotsk
# Processing Record 43 of Set 8 | oranjemund
# Processing Record 44 of Set 8 | les cayes
# Processing Record 45 of Set 8 | karratha
# Processing Record 46 of Set 8 | kourou
# Processing Record 47 of Set 8 | minas de marcona
# Processing Record 48 of Set 8 | bayanhongor
# Processing Record 49 of Set 8 | fortuna
# Processing Record 0 of Set 9 | francistown
# Processing Record 1 of Set 9 | reggane
# Processing Record 2 of Set 9 | jiagedaqi
# Processing Record 3 of Set 9 | bodaybo
# Processing Record 4 of Set 9 | provins
# Processing Record 5 of Set 9 | semnan
# Processing Record 6 of Set 9 | westport
# Processing Record 7 of Set 9 | quellon
# Processing Record 8 of Set 9 | lautoka
# Processing Record 9 of Set 9 | dolinsk
# Processing Record 10 of Set 9 | usogorsk
# Processing Record 11 of Set 9 | quirinopolis
# Processing Record 12 of Set 9 | yamada
# Processing Record 13 of Set 9 | demopolis
# Processing Record 14 of Set 9 | traralgon
# Processing Record 15 of Set 9 | la passe
# Processing Record 16 of Set 9 | kill devil hills
# Processing Record 17 of Set 9 | saint-pierre
# Processing Record 18 of Set 9 | czaplinek
# Processing Record 19 of Set 9 | kuqa
# Processing Record 20 of Set 9 | oskaloosa
# Processing Record 21 of Set 9 | tahe
# Processing Record 22 of Set 9 | paita
# Processing Record 23 of Set 9 | luau
# Processing Record 24 of Set 9 | nanakuli
# Processing Record 25 of Set 9 | salalah
# Processing Record 26 of Set 9 | chirilagua
# Processing Record 27 of Set 9 | aioun
# Processing Record 28 of Set 9 | cill airne
# Processing Record 29 of Set 9 | portage la prairie
# Processing Record 30 of Set 9 | roma
# Processing Record 31 of Set 9 | sale
# Processing Record 32 of Set 9 | bamboo flat
# Processing Record 33 of Set 9 | kenora
# Processing Record 34 of Set 9 | otjimbingwe
# Processing Record 35 of Set 9 | miyazu
# Processing Record 36 of Set 9 | nagqu
# Processing Record 37 of Set 9 | acarau
# Processing Record 38 of Set 9 | richmond
# Processing Record 39 of Set 9 | khunti
# Processing Record 40 of Set 9 | suphan buri
# Processing Record 41 of Set 9 | howard springs
# Processing Record 42 of Set 9 | guaymate
# Processing Record 43 of Set 9 | selkirk
# Processing Record 44 of Set 9 | puerto santa
# Processing Record 45 of Set 9 | ulanhot
# Processing Record 46 of Set 9 | vilyuysk
# Processing Record 47 of Set 9 | arno
# Processing Record 48 of Set 9 | muroto-misakicho
# Processing Record 49 of Set 9 | mayen abun
# City not found. Skipping...
# Processing Record 0 of Set 10 | taulaga
# Processing Record 1 of Set 10 | sohbatpur
# Processing Record 2 of Set 10 | praya
# Processing Record 3 of Set 10 | kirovo-chepetsk
# Processing Record 4 of Set 10 | sovetskoye
# Processing Record 5 of Set 10 | 'ibri
# City not found. Skipping...
# Processing Record 6 of Set 10 | levuka
# Processing Record 7 of Set 10 | qalat
# Processing Record 8 of Set 10 | nuku'alofa
# Processing Record 9 of Set 10 | weston
# Processing Record 10 of Set 10 | sao jose da coroa grande
# Processing Record 11 of Set 10 | namibe
# Processing Record 12 of Set 10 | el calafate
# Processing Record 13 of Set 10 | princeville
# Processing Record 14 of Set 10 | nguigmi
# Processing Record 15 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 16 of Set 10 | champerico
# Processing Record 17 of Set 10 | baiti
# Processing Record 18 of Set 10 | cachoeiro de itapemirim
# Processing Record 19 of Set 10 | diamantino
# Processing Record 20 of Set 10 | yuzhno-kurilsk
# Processing Record 21 of Set 10 | m'sila
# Processing Record 22 of Set 10 | sirte
# Processing Record 23 of Set 10 | korotchaevo
# City not found. Skipping...
# Processing Record 24 of Set 10 | smirnykh
# Processing Record 25 of Set 10 | awjilah
# Processing Record 26 of Set 10 | smithers
# Processing Record 27 of Set 10 | balqash
# Processing Record 28 of Set 10 | east london
# Processing Record 29 of Set 10 | saint-pierre-d'oleron
# City not found. Skipping...
# Processing Record 30 of Set 10 | bastad
# Processing Record 31 of Set 10 | itaituba
# Processing Record 32 of Set 10 | ust-nera
# Processing Record 33 of Set 10 | veraval
# Processing Record 34 of Set 10 | sevastopol
# Processing Record 35 of Set 10 | yuxia
# Processing Record 36 of Set 10 | khovd
# Processing Record 37 of Set 10 | la ronge
# Processing Record 38 of Set 10 | nogliki
# Processing Record 39 of Set 10 | kayangel
# Processing Record 40 of Set 10 | anton lizardo
# Processing Record 41 of Set 10 | mumbwa
# Processing Record 42 of Set 10 | timimoun
# Processing Record 43 of Set 10 | salekhard
# Processing Record 44 of Set 10 | tsiombe
# Processing Record 45 of Set 10 | south hedland
# Processing Record 46 of Set 10 | piovene rocchette
# Processing Record 47 of Set 10 | posto fiscal rolim de moura
# Processing Record 48 of Set 10 | las tablas
# Processing Record 49 of Set 10 | nortelandia
# Processing Record 0 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 1 of Set 11 | port augusta
# Processing Record 2 of Set 11 | virarajendrapet
# Processing Record 3 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 4 of Set 11 | lazaro cardenas
# Processing Record 5 of Set 11 | santo antonio
# Processing Record 6 of Set 11 | altay
# Processing Record 7 of Set 11 | tsengel
# Processing Record 8 of Set 11 | xam nua
# Processing Record 9 of Set 11 | cururupu
# Processing Record 10 of Set 11 | waitara
# Processing Record 11 of Set 11 | tvoroyri
# Processing Record 12 of Set 11 | novyy turtkul'
# Processing Record 13 of Set 11 | pali
# Processing Record 14 of Set 11 | zouerate
# Processing Record 15 of Set 11 | springbok
# Processing Record 16 of Set 11 | zhangye
# Processing Record 17 of Set 11 | minacu
# City not found. Skipping...
# Processing Record 18 of Set 11 | kimberley
# Processing Record 19 of Set 11 | guiuan
# Processing Record 20 of Set 11 | mulanje
# Processing Record 21 of Set 11 | malindi
# Processing Record 22 of Set 11 | vitorino freire
# Processing Record 23 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 24 of Set 11 | la baneza
# Processing Record 25 of Set 11 | ejido benito juarez
# City not found. Skipping...
# Processing Record 26 of Set 11 | jayapura
# Processing Record 27 of Set 11 | kargopol'
# Processing Record 28 of Set 11 | mantua
# Processing Record 29 of Set 11 | porbandar
# Processing Record 30 of Set 11 | nambucca heads
# Processing Record 31 of Set 11 | joshimath
# Processing Record 32 of Set 11 | altai
# Processing Record 33 of Set 11 | devonport
# Processing Record 34 of Set 11 | notodden
# Processing Record 35 of Set 11 | talata mafara
# Processing Record 36 of Set 11 | tarija
# Processing Record 37 of Set 11 | pointe aux piments
# Processing Record 38 of Set 11 | nishinoomote
# Processing Record 39 of Set 11 | walvis bay
# Processing Record 40 of Set 11 | qamdo
# Processing Record 41 of Set 11 | manggar
# Processing Record 42 of Set 11 | weno
# Processing Record 43 of Set 11 | kolomna
# Processing Record 44 of Set 11 | leskovac
# Processing Record 45 of Set 11 | baardheere
# Processing Record 46 of Set 11 | saudarkrokur
# Processing Record 47 of Set 11 | holualoa
# Processing Record 48 of Set 11 | weligama
# Processing Record 49 of Set 11 | hauterive
# Processing Record 0 of Set 12 | praia da vitoria
# Processing Record 1 of Set 12 | hami
# Processing Record 2 of Set 12 | guozhen
# Processing Record 3 of Set 12 | santa vitoria do palmar
# Processing Record 4 of Set 12 | bikenibeu village
# Processing Record 5 of Set 12 | changleng
# Processing Record 6 of Set 12 | kallar kahar
# Processing Record 7 of Set 12 | cockburn town
# Processing Record 8 of Set 12 | peace river
# Processing Record 9 of Set 12 | plessisville
# Processing Record 10 of Set 12 | kindu
# Processing Record 11 of Set 12 | taroa
# Processing Record 12 of Set 12 | nova sintra
# Processing Record 13 of Set 12 | marsala
# Processing Record 14 of Set 12 | vung tau
# Processing Record 15 of Set 12 | marat
# Processing Record 16 of Set 12 | tshabong
# Processing Record 17 of Set 12 | san luis de la loma
# Processing Record 18 of Set 12 | butwal
# Processing Record 19 of Set 12 | dryden
# Processing Record 20 of Set 12 | puerto leguizamo
# Processing Record 21 of Set 12 | kapa'a
# Processing Record 22 of Set 12 | salinas
# Processing Record 23 of Set 12 | boguchany
# Processing Record 24 of Set 12 | al hudaydah
# Processing Record 25 of Set 12 | bardai
# Processing Record 26 of Set 12 | jesus menendez
# City not found. Skipping...
# Processing Record 27 of Set 12 | pospelikha
# Processing Record 28 of Set 12 | sambava
# Processing Record 29 of Set 12 | coronel suarez
# Processing Record 30 of Set 12 | pagar alam
# Processing Record 31 of Set 12 | kutulik
# Processing Record 32 of Set 12 | formosa
# Processing Record 33 of Set 12 | kawthoung
# City not found. Skipping...
# Processing Record 34 of Set 12 | san salvador de jujuy
# Processing Record 35 of Set 12 | miyako
# Processing Record 36 of Set 12 | omdurman
# Processing Record 37 of Set 12 | manismata
# Processing Record 38 of Set 12 | naze
# Processing Record 39 of Set 12 | blackwater
# Processing Record 40 of Set 12 | burang
# Processing Record 41 of Set 12 | bijie
# Processing Record 42 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 43 of Set 12 | hafar al-batin
# Processing Record 44 of Set 12 | mahalapye
# Processing Record 45 of Set 12 | mata-utu
# Processing Record 46 of Set 12 | lompoc
# Processing Record 47 of Set 12 | al qubbah
# Processing Record 48 of Set 12 | sassandra
# Processing Record 49 of Set 12 | marine corps base hawaii - mcbh
# Processing Record 0 of Set 13 | isangel
# Processing Record 1 of Set 13 | divnomorskoye
# Processing Record 2 of Set 13 | shambu
# Processing Record 3 of Set 13 | vygonichi
# Processing Record 4 of Set 13 | markovo
# Processing Record 5 of Set 13 | kalmunai
# Processing Record 6 of Set 13 | panjab
# Processing Record 7 of Set 13 | angra do heroismo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a DataFrame from the cities list
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                 invercargill -46.4000  168.3500      9.45        98
# 1                      plastun  44.7561  136.2939     12.81        37
# 2  edinburgh of the seven seas -37.0676  -12.3116     17.84        80
# 3                       uturoa -16.7333 -151.4333     29.26        76
# 4                    adamstown -25.0660 -130.1015     21.43        83
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        3.58      NZ  1712806996
# 1          99        3.53      RU  1712807166
# 2         100        1.40      SH  1712806958
# 3          20        8.92      PF  1712807168
# 4         100        8.11      PN  1712806958

# %%
# Export the City_Data into a csv
city_data_df.to_csv('../output_data/cities.csv', index_label='City_ID')

# %%
# Read saved data
city_data_df = pd.read_csv('../output_data/cities.csv', index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       invercargill -46.4000  168.3500      9.45        98
# 1                            plastun  44.7561  136.2939     12.81        37
# 2        edinburgh of the seven seas -37.0676  -12.3116     17.84        80
# 3                             uturoa -16.7333 -151.4333     29.26        76
# 4                          adamstown -25.0660 -130.1015     21.43        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.58      NZ  1712806996
# 1                99        3.53      RU  1712807166
# 2               100        1.40      SH  1712806958
# 3                20        8.92      PF  1712807168
# 4               100        8.11      PN  1712806958

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], color='skyblue', edgecolors='black', alpha=0.75)

# Incorporate other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig('../output_data/Fig1.png')

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], color='skyblue', edgecolors='black', alpha=0.75)

# Incorporate other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig('../output_data/Fig1.png')

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for Latitude vs. Cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"],  color='skyblue', edgecolors='black', alpha=0.75)

# Set the title and labels
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig('../output_data/Fig1.png')

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for Latitude vs. Wind Speed

plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], color='lightblue', edgecolors='black', alpha=0.75)

# Set the title and labels
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig('../output_data/Fig1.png')

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x, y):
    slope, intercept, rvalue, pvalue, stderr = stats.linregress(x, y)
    regress_values = x * slope + intercept
    return regress_values, slope, intercept, rvalue, pvalue, stderr

# %%
# Create a DataFrame for the Northern Hemisphere data
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                      plastun  44.7561  136.2939     12.81        37
# 5                  el porvenir  13.7617  -87.3458     26.63        78
# 6                 cole harbour  44.6724  -63.4751      2.74        86
# 7        isola di capo rizzuto  38.9600   17.0933     13.99        74
# 8                    ilulissat  69.2167  -51.1000     -9.99        67
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                99        3.53      RU  1712807166
# 5                60        0.85      HN  1712807171
# 6                99        0.72      CA  1712807067
# 7               100        2.67      IT  1712807174
# 8               100        0.00      GL  1712806995

# %%
# Create a DataFrame for the Southern Hemisphere data
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       invercargill -46.4000  168.3500      9.45        98
# 2        edinburgh of the seven seas -37.0676  -12.3116     17.84        80
# 3                             uturoa -16.7333 -151.4333     29.26        76
# 4                          adamstown -25.0660 -130.1015     21.43        83
# 11                       antofagasta -23.6500  -70.4000     18.60        90
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.58      NZ  1712806996
# 2               100        1.40      SH  1712806958
# 3                20        8.92      PF  1712807168
# 4               100        8.11      PN  1712806958
# 11               80        2.12      CL  1712807178

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
def linear_regression(x, y):
    slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
    regress_values = x * slope + intercept
    return regress_values, slope, intercept, rvalue, pvalue, stderr

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Perform linear regression
(regress_values, slope, intercept, rvalue, pvalue, std_err) = linear_regression(x=x_values, y=y_values)
regression_line = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
# Plot the scatter plot and regression line
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='red')

plt.text(x_values.min(), y_values.min(), regression_line, color='black', fontsize=12)
# Print the R-value
print(f"R-value: {rvalue}")

plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Northern Hemisphere: Max Temp vs. Latitude Linear Regression')
plt.show()
# Out:
# R-value: -0.8750196461501155

# %%
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Get x and y values for the Southern Hemisphere analysis
x_values_southern = southern_hemi_df["Lat"]
y_values_southern = southern_hemi_df["Max Temp"]

# Perform linear regression for the Southern Hemisphere
regress_values_southern, slope_southern, intercept_southern, rvalue_southern, pvalue_southern, std_err_southern = linear_regression(x=x_values_southern, y=y_values_southern)

# Create the regression line equation for the Southern Hemisphere
regression_line_southern = f"y = {round(slope_southern, 2)}x + {round(intercept_southern, 2)}"

# Print the R-value for the Southern Hemisphere
print(f"R-value (Southern Hemisphere): {rvalue_southern}")

# Plot the scatter plot and regression line for the Southern Hemisphere
plt.scatter(x_values_southern, y_values_southern)
plt.plot(x_values_southern, regress_values_southern, color='red')

# Add the regression equation to the plot for the Southern Hemisphere
plt.text(x_values_southern.min(), y_values_southern.min(), regression_line_southern, color='black', fontsize=12)

# Set plot labels and title for the Southern Hemisphere
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Southern Hemisphere: Max Temp vs. Latitude Linear Regression')

# Show the plot for the Southern Hemisphere
plt.show()
# Out:
# R-value (Southern Hemisphere): 0.7428744040867491

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
x_values_northern_humidity = northern_hemi_df["Lat"]
y_values_northern_humidity = northern_hemi_df["Humidity"]

# Perform linear regression for Humidity vs. Latitude in the Northern Hemisphere
regress_values_northern_humidity, slope_northern_humidity, intercept_northern_humidity, rvalue_northern_humidity, pvalue_northern_humidity, std_err_northern_humidity = linear_regression(x=x_values_northern_humidity, y=y_values_northern_humidity)

# Create the regression line equation for Humidity vs. Latitude in the Northern Hemisphere
regression_line_northern_humidity = f"y = {round(slope_northern_humidity, 2)}x + {round(intercept_northern_humidity, 2)}"

# Print the R-value for Humidity vs. Latitude in the Northern Hemisphere
print(f"R-value (Northern Hemisphere - Humidity vs. Latitude): {rvalue_northern_humidity}")

# Plot the scatter plot and regression line for Humidity vs. Latitude in the Northern Hemisphere
plt.scatter(x_values_northern_humidity, y_values_northern_humidity)
plt.plot(x_values_northern_humidity, regress_values_northern_humidity, color='red')

# Add the regression equation to the plot for Humidity vs. Latitude in the Northern Hemisphere
plt.text(x_values_northern_humidity.min(), y_values_northern_humidity.min(), regression_line_northern_humidity, color='black', fontsize=12)

# Set plot labels and title for Humidity vs. Latitude in the Northern Hemisphere
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere: Humidity vs. Latitude Linear Regression')

# Show the plot for Humidity vs. Latitude in the Northern Hemisphere
plt.show()
# Out:
# R-value (Northern Hemisphere - Humidity vs. Latitude): 0.2508558888948356

# %%
x_values_southern_humidity = southern_hemi_df["Lat"]
y_values_southern_humidity = southern_hemi_df["Humidity"]

# Perform linear regression for Humidity vs. Latitude in the Southern Hemisphere
regress_values_southern_humidity, slope_southern_humidity, intercept_southern_humidity, rvalue_southern_humidity, pvalue_southern_humidity, std_err_southern_humidity = linear_regression(x=x_values_southern_humidity, y=y_values_southern_humidity)

# Create the regression line equation for Humidity vs. Latitude in the Southern Hemisphere
regression_line_southern_humidity = f"y = {round(slope_southern_humidity, 2)}x + {round(intercept_southern_humidity, 2)}"

# Print the R-value for Humidity vs. Latitude in the Southern Hemisphere
print(f"R-value (Southern Hemisphere - Humidity vs. Latitude): {rvalue_southern_humidity}")

# Plot the scatter plot and regression line for Humidity vs. Latitude in the Southern Hemisphere
plt.scatter(x_values_southern_humidity, y_values_southern_humidity)
plt.plot(x_values_southern_humidity, regress_values_southern_humidity, color='red')

# Add the regression equation to the plot for Humidity vs. Latitude in the Southern Hemisphere
plt.text(x_values_southern_humidity.min(), y_values_southern_humidity.min(), regression_line_southern_humidity, color='black', fontsize=12)

# Set plot labels and title for Humidity vs. Latitude in the Southern Hemisphere
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere: Humidity vs. Latitude Linear Regression')

# Show the plot for Humidity vs. Latitude in the Southern Hemisphere
plt.show()
# Out:
# R-value (Southern Hemisphere - Humidity vs. Latitude): 0.2362151946511595

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
x_values_northern_cloudiness = northern_hemi_df["Lat"]
y_values_northern_cloudiness = northern_hemi_df["Cloudiness"]

# Perform linear regression for Cloudiness vs. Latitude in the Northern Hemisphere
regress_values_northern_cloudiness, slope_northern_cloudiness, intercept_northern_cloudiness, rvalue_northern_cloudiness, pvalue_northern_cloudiness, std_err_northern_cloudiness = linear_regression(x=x_values_northern_cloudiness, y=y_values_northern_cloudiness)

# Create the regression line equation for Cloudiness vs. Latitude in the Northern Hemisphere
regression_line_northern_cloudiness = f"y = {round(slope_northern_cloudiness, 2)}x + {round(intercept_northern_cloudiness, 2)}"

# Print the R-value for Cloudiness vs. Latitude in the Northern Hemisphere
print(f"R-value (Northern Hemisphere - Cloudiness vs. Latitude): {rvalue_northern_cloudiness}")

# Plot the scatter plot and regression line for Cloudiness vs. Latitude in the Northern Hemisphere
plt.scatter(x_values_northern_cloudiness, y_values_northern_cloudiness)
plt.plot(x_values_northern_cloudiness, regress_values_northern_cloudiness, color='red')

# Add the regression equation to the plot for Cloudiness vs. Latitude in the Northern Hemisphere
plt.text(x_values_northern_cloudiness.min(), y_values_northern_cloudiness.min(), regression_line_northern_cloudiness, color='black', fontsize=12)

# Set plot labels and title for Cloudiness vs. Latitude in the Northern Hemisphere
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere: Cloudiness vs. Latitude Linear Regression')

# Show the plot for Cloudiness vs. Latitude in the Northern Hemisphere
plt.show()
# Out:
# R-value (Northern Hemisphere - Cloudiness vs. Latitude): 0.22028935158196417

# %%
x_values_southern_cloudiness = southern_hemi_df["Lat"]
y_values_southern_cloudiness = southern_hemi_df["Cloudiness"]

# Perform linear regression for Cloudiness vs. Latitude in the Southern Hemisphere
regress_values_southern_cloudiness, slope_southern_cloudiness, intercept_southern_cloudiness, rvalue_southern_cloudiness, pvalue_southern_cloudiness, std_err_southern_cloudiness = linear_regression(x=x_values_southern_cloudiness, y=y_values_southern_cloudiness)

# Create the regression line equation for Cloudiness vs. Latitude in the Southern Hemisphere
regression_line_southern_cloudiness = f"y = {round(slope_southern_cloudiness, 2)}x + {round(intercept_southern_cloudiness, 2)}"

# Print the R-value for Cloudiness vs. Latitude in the Southern Hemisphere
print(f"R-value (Southern Hemisphere - Cloudiness vs. Latitude): {rvalue_southern_cloudiness}")

# Plot the scatter plot and regression line for Cloudiness vs. Latitude in the Southern Hemisphere
plt.scatter(x_values_southern_cloudiness, y_values_southern_cloudiness)
plt.plot(x_values_southern_cloudiness, regress_values_southern_cloudiness, color='red')

# Add the regression equation to the plot for Cloudiness vs. Latitude in the Southern Hemisphere
plt.text(x_values_southern_cloudiness.min(), y_values_southern_cloudiness.min(), regression_line_southern_cloudiness, color='black', fontsize=12)

# Set plot labels and title for Cloudiness vs. Latitude in the Southern Hemisphere
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere: Cloudiness vs. Latitude Linear Regression')

# Show the plot for Cloudiness vs. Latitude in the Southern Hemisphere
plt.show()
# Out:
# R-value (Southern Hemisphere - Cloudiness vs. Latitude): 0.2755031814709724

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
x_values_northern_wind = northern_hemi_df["Lat"]
y_values_northern_wind = northern_hemi_df["Wind Speed"]

# Perform linear regression for Wind Speed vs. Latitude in the Northern Hemisphere
regress_values_northern_wind, slope_northern_wind, intercept_northern_wind, rvalue_northern_wind, pvalue_northern_wind, std_err_northern_wind = linear_regression(x=x_values_northern_wind, y=y_values_northern_wind)

# Create the regression line equation for Wind Speed vs. Latitude in the Northern Hemisphere
regression_line_northern_wind = f"y = {round(slope_northern_wind, 2)}x + {round(intercept_northern_wind, 2)}"

# Print the R-value for Wind Speed vs. Latitude in the Northern Hemisphere
print(f"R-value (Northern Hemisphere - Wind Speed vs. Latitude): {rvalue_northern_wind}")

# Plot the scatter plot and regression line for Wind Speed vs. Latitude in the Northern Hemisphere
plt.scatter(x_values_northern_wind, y_values_northern_wind)
plt.plot(x_values_northern_wind, regress_values_northern_wind, color='red')

# Add the regression equation to the plot for Wind Speed vs. Latitude in the Northern Hemisphere
plt.text(x_values_northern_wind.min(), y_values_northern_wind.min(), regression_line_northern_wind, color='black', fontsize=12)

# Set plot labels and title for Wind Speed vs. Latitude in the Northern Hemisphere
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Northern Hemisphere: Wind Speed vs. Latitude Linear Regression')

# Show the plot for Wind Speed vs. Latitude in the Northern Hemisphere
plt.show()
# Out:
# R-value (Northern Hemisphere - Wind Speed vs. Latitude): 0.06913143520513718

# %%
x_values_southern_wind = southern_hemi_df["Lat"]
y_values_southern_wind = southern_hemi_df["Wind Speed"]

# Perform linear regression for Wind Speed vs. Latitude in the Southern Hemisphere
regress_values_southern_wind, slope_southern_wind, intercept_southern_wind, rvalue_southern_wind, pvalue_southern_wind, std_err_southern_wind = linear_regression(x=x_values_southern_wind, y=y_values_southern_wind)

# Create the regression line equation for Wind Speed vs. Latitude in the Southern Hemisphere
regression_line_southern_wind = f"y = {round(slope_southern_wind, 2)}x + {round(intercept_southern_wind, 2)}"

# Print the R-value for Wind Speed vs. Latitude in the Southern Hemisphere
print(f"R-value (Southern Hemisphere - Wind Speed vs. Latitude): {rvalue_southern_wind}")

# Plot the scatter plot and regression line for Wind Speed vs. Latitude in the Southern Hemisphere
plt.scatter(x_values_southern_wind, y_values_southern_wind)
plt.plot(x_values_southern_wind, regress_values_southern_wind, color='red')

# Add the regression equation to the plot for Wind Speed vs. Latitude in the Southern Hemisphere
plt.text(x_values_southern_wind.min(), y_values_southern_wind.min(), regression_line_southern_wind, color='black', fontsize=12)

# Set plot labels and title for Wind Speed vs. Latitude in the Southern Hemisphere
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Southern Hemisphere: Wind Speed vs. Latitude Linear Regression')

# Show the plot for Wind Speed vs. Latitude in the Southern Hemisphere
plt.show()
# Out:
# R-value (Southern Hemisphere - Wind Speed vs. Latitude): -0.360127492602425

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
